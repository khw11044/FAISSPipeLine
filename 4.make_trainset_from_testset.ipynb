# %%
from langchain.document_loaders import UnstructuredPDFLoader

# %%
import glob
import os

# %%
from unstructured.partition.pdf import partition_pdf


def extract_pdf_elements(filepath):
    """
    PDF 파일에서 이미지, 테이블, 그리고 텍스트 조각을 추출합니다.
    path: 이미지(.jpg)를 저장할 파일 경로
    fname: 파일 이름
    """
    return partition_pdf(
        filename=filepath,
        extract_images_in_pdf=False,  # PDF 내 이미지 추출 활성화
        infer_table_structure=False,  # 테이블 구조 추론 활성화
        chunking_strategy="by_title",  # 제목별로 텍스트 조각화
        max_characters=4000,  # 최대 문자 수
        new_after_n_chars=3800,  # 이 문자 수 이후에 새로운 조각 생성
        combine_text_under_n_chars=2000,  # 이 문자 수 이하의 텍스트는 결합
    )

# %%
test_sources = os.listdir("../open/test_source")
print(test_sources)
# Out:
# ['「FIS 이슈 & 포커스」 22-4호 《중앙-지방 간 재정조정제도》.pdf', '「FIS 이슈 & 포커스」 23-2호 《핵심재정사업 성과관리》.pdf', '「FIS 이슈 & 포커스」(신규) 통권 제1호 《우발부채》.pdf', '「FIS 이슈&포커스」 22-2호 《재정성과관리제도》.pdf', '국토교통부_행복주택출자.pdf', '보건복지부_노인장기요양보험 사업운영.pdf', '보건복지부_부모급여(영아수당) 지원.pdf', '산업통상자원부_에너지바우처.pdf', '중소벤처기업부_혁신창업사업화자금(융자).pdf']

# %%
test_sources[1]
# Out:
# '「FIS 이슈 & 포커스」 23-2호 《핵심재정사업 성과관리》.pdf'

# %%
elements = extract_pdf_elements('./중소벤처기업부_혁신창업사업화자금(융자).pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\kim_h\anaconda3\envs\unst\lib\site-packages\unstructured_pytesseract\pytesseract.py:451, in get_tesseract_version()
#     450 try:
# --> 451     output = subprocess.check_output(
#     452         [tesseract_cmd, '--version'],
#     453         stderr=subprocess.STDOUT,
#     454         env=environ,
#     455         stdin=subprocess.DEVNULL,
#     456     )
#     457 except OSError:
#
# File c:\Users\kim_h\anaconda3\envs\unst\lib\subprocess.py:424, in check_output(timeout, *popenargs, **kwargs)
#     422     kwargs['input'] = empty
# --> 424 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425            **kwargs).stdout
#
# File c:\Users\kim_h\anaconda3\envs\unst\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503     kwargs['stderr'] = PIPE
# ...

# %%
elements = []
for path in test_sources:
    extract_pdf_elements(path)

# %%
# PDF 파일 로드
elements = extract_pdf_elements("../open/SPRI_AI_Brief_2023년12월호_F.pdf")
